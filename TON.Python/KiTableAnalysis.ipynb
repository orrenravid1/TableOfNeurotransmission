# %%
import pandas as pd
import os

# %%
ki_db = pd.read_csv(os.path.join("..", "res", "PDPS", "KiDatabase.csv"))
unique_receptors = ki_db["Name"].unique()
unique_receptors.sort()
unique_receptors
# Out:
# array([' Adrenaline Alpha1', ' Alpha2B', '(+) CIMBI-772', ...,
#        'thyrotropin-releasing hormone R3',
#        'trace amine-associated receptor', 'tryptamine'], dtype=object)

# %%
ki_db_human = ki_db[ki_db["species"].str.lower() == "human"]
unique_human_receptors = ki_db_human["Name"].unique()
unique_human_receptors.sort()
unique_human_receptors
# Out:
# array([' Alpha2B', '(+) CIMBI-772', '(+)CIMBI-775', '(-) CIMBI-772',
#        '(-)CIMBI-775', '1200015E14Rik', '17Beta-HSD Type 3',
#        '3-Ethyl-3-{4-[4-(3-hydroxyphenyl)piperazin-1-yl]butyl}-1,3-dihydro-2H-indol-2-one',
#        '3-{4-[4-(4-Chlorophenyl)piperazin-1-yl]butyl}-1,3-dimethyl-1,3-dihydro-2H-indol-2-one',
#        '3-{4-[4-(4-Chlorophenyl)piperazin-1-yl]butyl}-3-(2-fluoroethyl)-1,3-dihydro-2H-indol-2-one',
#        '3-{4-[4-(4-Chlorophenyl)piperazin-1-yl]butyl}-3-methyl-1,3-dihydro-2H-indol-2-one',
#        '3-{4-[4-(4-Chlorophenyl)piperazin-1-yl]butyl}-3-propyl-1,3-dihydro-2H-indol-2-one',
#        '5-HT Transporter', '5-HT1', '5-HT1A', '5-HT1B', '5-HT1D',
#        '5-HT1DBeta', '5-HT1E', '5-HT1F', '5-HT2', '5-HT2A', '5-HT2B',
#        '5-HT2C', '5-HT2C-INI', '5-HT2c VGI', '5-HT3', '5-HT4', '5-HT4L',
#        '5-HT4S', '5-HT4a', '5-HT4b', '5-HT4c', '5-HT4d', '5-HT4hb',
#        '5-HT5', '5-HT5a', '5-HT6', '5-HT7', '5-HT7A', '5-HT7L', '5-HT7S',
#        '5-HT7b', '5-Lipoxygenase', '5HT Transporter', 'A2', 'A3', 'A4',
#        'AChE', 'ADENOSINE', 'ADENOSINE A1', 'ADENOSINE A2',
#        'ADENOSINE A2B', 'ADENOSINE A2a', 'ADENOSINE A3', 'AMPA',
#        'ANGIOTENSIN AT1', 'AP2 associated kinase 1', 'ATPase (Na+, K+)',
#        'Ac-AChBP', 'Acetylcholinesterase', 'Activated p21cdc42Hs kinase',
#        'Adenosine Kinase, AK', 'Adenosine transporter',
#        'Adrenaline alpha1', 'Adrenergic Alpha', 'Adrenomedullin AM1',
#        'Adrenomedullin AM2', 'Alpha 1 Adrenergic Receptor',
#        'Alpha 1A Adrenergic Receptor', 'Alpha 1B Adrenergic Receptor',
#        'Alpha 2 Adrenergic Receptor', 'Alpha 2A Adrenergic Receptor',
#        'Alpha 2B Adrenergic Receptor', 'Alpha 2C Adrenergic Receptor',
#        'Alpha-1A', 'Alpha-1B', 'Alpha-2A', 'Alpha1D', 'Alpha2A',
#        'Alpha2B', 'Alpha2C', 'Anaphylatoxin C5a',
#        'Anaplastic lymphoma kinase (Ki-1)', 'Androgen Receptor',
#        'Angiotensin AT2', 'Angiotensin II AT1 ', 'Angiotensin II AT2',
#        'Angiotensin-converting enzyme, ACE', 'Apelin', 'Aurora kinase C',
#        'B lymphoid tyrosine kinase', 'B1 BRADYKININ', 'B2',
#        'B2 BRADYKININ', 'B3', 'BChE', 'BMP2 inducible kinase',
#        'BMX non-receptor tyrosine kinase', 'BZP', 'BZP Rat Brain Site',
#        'Benzodiazepine central', 'Benzodiazepine peripheral', 'Beta 1',
#        'Beta 2', 'Beta 3', 'Beta-1', 'Beta-2', 'Beta-Amyloid (1-40)',
#        'Beta-Amyloid (1-42)', 'Bile Salt Export Pump, BSEP', 'Bombesin 3',
#        'Bombesin BB1', 'Bombesin BB2', 'Bombesin BB3', 'Bradykinin B1',
#        'Bradykinin B2', 'Bruton agammaglobulinemia tyrosine kinase',
#        'C-src tyrosine kinase', 'CANNABINOID CB1', 'CANNABINOID CB2',
#        'CB1', 'CB2', 'CDC-like kinase 1', 'CDC-like kinase 2',
#        'CDC-like kinase 3', 'CDC-like kinase 4', 'CDK1', 'CDK2', 'CDK4',
#        'CDK5 activator-binding protein C53', 'CGRP', 'CGRP1', 'CIMBI-712',
#        'CIMBI-717', 'CIMBI-772', 'CIMBI-775', 'COX-1', 'COX-2',
#        'CRF-R2 Alpha', 'CRF1', 'Calcitonin',
#        'Calcitonin Gene-related Peptide (CGRP)', 'Calcium channel',
#        'Calcium channel (DHP)', 'Calcium channel (Type L)',
#        'Calcium channel (Type N)', 'Calcium channel diltiazem',
#        'Calcium channel verapamil binding site',
#        'Calcium/calmodulin-dependent protein kinase (CaM kinase) II alpha',
#        'Calcium/calmodulin-dependent protein kinase (CaM kinase) II beta',
#        'Calcium/calmodulin-dependent protein kinase (CaM kinase) II delta',
#        'Calcium/calmodulin-dependent protein kinase (CaM kinase) II gamma',
#        'Calcium/calmodulin-dependent protein kinase I',
#        'Calcium/calmodulin-dependent protein kinase ID',
#        'Calcium/calmodulin-dependent protein kinase IG',
#        'Calcium/calmodulin-dependent protein kinase kinase 1, alpha',
#        'Calcium/calmodulin-dependent protein kinase kinase 2, beta',
#        'Carbonic Anhydrase Isozymes, CA I',
#        'Carbonic Anhydrase Isozymes, CA II',
#        'Carbonic Anhydrase Isozymes, CA IX', 'Carboxypeptidase CPG2',
#        'Casein kinase 1, epsilon', 'Casein kinase 1, gamma 1',
#        'Casein kinase 1, gamma 2', 'Cathepsin D',
#        'Chemoattractant receptor-homologous, CRTH2', 'Chemokine CCR1',
#        'Chemokine CCR2B', 'Chemokine CCR4', 'Chemokine CCR5',
#        'Chemokine CX3CR1', 'Chemokine CXCR1', 'Chemokine CXCR2',
#        'Chemokine CXCR3', 'Chemokine US28', 'Chloride channel, TBOB',
#        'Cholecystokinin', 'Cholecystokinin A', 'Cholecystokinin B',
#        'Choline Uptake', 'Cholinergic, Nicotinic Alpha1Beta1DeltaGamma',
#        'Cholinergic, Nicotinic Alpha1Beta2',
#        'Cholinergic, Nicotinic Alpha2Beta2',
#        'Cholinergic, Nicotinic Alpha2Beta4',
#        'Cholinergic, Nicotinic Alpha3Beta2',
#        'Cholinergic, Nicotinic Alpha3Beta4',
#        'Cholinergic, Nicotinic Alpha3Beta4x',
#        'Cholinergic, Nicotinic Alpha4Beta2',
#        'Cholinergic, Nicotinic Alpha4Beta2**',
#        'Cholinergic, Nicotinic Alpha4Beta2X',
#        'Cholinergic, Nicotinic Alpha4Beta4',
#        'Cholinergic, Nicotinic Alpha6Beta3Beta4Alpha5',
#        'Cholinergic, Nicotinic Alpha7', 'Cholinergic, muscarinic',
#        'Cholinergic, muscarinic M1', 'Cholinergic, muscarinic M2',
#        'Cholinergic, muscarinic M3', 'Cholinergic, muscarinic M4',
#        'Cholinergic, muscarinic M5', 'Cholinergic, nicotinic Alpha1',
#        'Ct-AChBP', 'Cyclin G associated kinase',
#        'Cyclin-dependent kinase 2', 'D1', 'D2', 'D2L', 'D2S', 'D3', 'D4',
#        'D4.4', 'D5', 'DAT', 'DOP', 'DOPAMINE D1', 'DOPAMINE D2',
#        'DOPAMINE D2 Long', 'DOPAMINE D2 Short', 'DOPAMINE D3',
#        'DOPAMINE D4', 'DOPAMINE D4.2', 'DOPAMINE D4.4', 'DOPAMINE D5',
#        'DOR', 'DP1', 'Death-associated kinase 3',
#        'Death-associated protein kinase 2', 'Delta',
#        'Delta Opiate Receptor', 'Dihyrofolate Reductase, DHFR',
#        'Dipeptidyl peptidase DPP II', 'Dipeptidyl peptidase DPP IV',
#        'Dopamine D1A', 'Dopamine D2A', 'Dopamine Transporter',
#        'Dopamine2-like', 'EGF', 'EGF-R', 'ENDOTHELIN A', 'ENDOTHELIN B',
#        'EP1', 'EP2', 'EP3', 'EP4', 'EPH receptor A2', 'EPH receptor A3',
#        'EPH receptor A4', 'EPH receptor A5', 'EPH receptor A6',
#        'EPH receptor A7', 'EPH receptor A8', 'EPH receptor B1',
#        'EPH receptor B2', 'EPH receptor B4',
#        'Epidermal growth factor receptor', 'Erythropietin EPOR',
#        'Estrogen receptor alpha', 'Estrogen receptor beta',
#        'Excitatory Amino Acid EAAT1', 'Excitatory Amino Acid EAAT2',
#        'Excitatory Amino Acid EAAT3', 'Export Pump, ABCC2', 'FGF-R2',
#        'FGFR-1, (FL)', 'FGFR-1, (cyto)', 'FP',
#        'FYN oncogene related to SRC, FGR, YES',
#        'Fatty Acid Amide Hydrolic, FAAH',
#        'Fer (fps/fes related) tyrosine kinase (phosphoprotein NCP94)',
#        'Fibroblast growth factor receptor 1 ',
#        'Fibroblast growth factor receptor 2',
#        'Fibroblast growth factor receptor 3',
#        'Fms-related tyrosine kinase 3', 'Fms-related tyrosine kinase 4',
#        'Follicle-Stimulating Hormone, FSH', 'Formyl peptide Receptor',
#        'Fyn-related kinase', 'GABA', 'GABA A', 'GABA A Alpha1Beta1Gamma2',
#        'GABA A Alpha1Beta2Gamma2', 'GABA A Alpha1Beta3Gamma2',
#        'GABA A Alpha2Beta1Gamma2', 'GABA A Alpha2Beta3Gamma2',
#        'GABA A Alpha3Beta1Gamma2', 'GABA A Alpha3Beta3Gamma2',
#        'GABA A Alpha4Beta2Gamma2', 'GABA A Alpha4Beta3Gamma2',
#        'GABA A Alpha4Gamma2', 'GABA A Alpha5Beta1Gamma2',
#        'GABA A Alpha5Beta3Gamma2', 'GABA A Alpha6Beta2Gamma2',
#        'GABA A Alpha6Beta3Gamma2', 'GABA A Benzodiazepine',
#        'GABA A alpha1', 'GABA A alpha2', 'GABA A alpha3', 'GABA A alpha5',
#        'GABA A alpha6', 'GABA B', 'GABA B rho 1', 'GABA B1A', 'GABA B1B',
#        'GABA C', 'GABA alpha1beta3gamma2', 'GABA alpha2beta3gamma2',
#        'GABA alpha3beta3gamma2', 'GABA alpha4beta3gamma2',
#        'GABA alpha5beta3gamma2', 'GABA alpha6beta3gamma2', 'GABA uptake',
#        'GABA-A', 'GABAA', 'GABAA alpha1beta3gamma2',
#        'GABAA alpha2beta3gamma2', 'GABAA alpha3beta3gamma2',
#        'GABAA alpha4beta3gamma2', 'GABAA alpha5beta3gamma2',
#        'GABAA alpha6beta3gamma2', 'GALANIN', 'GPR103', 'GPR109B', 'GPR7',
#        'GPR8', 'GR Alkaline Fosfatase', 'GSK-3', 'Galanin R1',
#        'Galanin R2', 'Galanin R3',
#        'Gardner-Rasheed feline sarcoma viral (v-fgr) oncogene homolog',
#        'Gastrin-Releasing peptide', 'Glucocorticoid',
#        'Glucocorticoid receptor', 'Glutamate AMPA 1', 'Glutamate AMPA 2',
#        'Glutamate AMPA 4', 'Glutamate, GluR1', 'Glutamate, GluR2',
#        'Glutamate, GluR4', 'Glutamate, GluR6 + KA2', 'Glutamate, GluR7',
#        'Glutamate-AMPA', 'Glutamate-Kainate', 'Glutamate-Kainate 5',
#        'Glutamate-Kainate 7', 'Glutamate-Kainate EAA1',
#        'Glutamate-Kainate, GluR5', 'Glutamate-Kainate, GluR6',
#        'Glutamate-NMDA', 'Glutamate-NMDA-MK801', 'Glutaminyl cyclase',
#        'Glycine', 'Glycine-1-transporter', 'Glycine-2-transporter',
#        'Glycogen synthase kinase 3',
#        'Gonadotropin-Releasing Hormone, GnRH-R', 'Growth Hormone',
#        'Growth Hormone Secretagogue Receptor', 'H1', 'H2', 'H3', 'H4',
#        'HERG', 'HISTAMINE H1', 'HISTAMINE H2', 'HISTAMINE H3',
#        'HISTAMINE H4', 'HIV-1 Protease Receptor ',
#        'Hemopoietic cell kinase', 'Histamine H2-Gs alpha S',
#        'Histamine H3L', 'Histaminergic H2', 'Hypocretin receptor 1',
#        'Hypocretin receptor 2', 'IKr', 'IKv1.1', 'IKv1.5', 'IP', 'IRK1',
#        'Iks', 'Imidazoline 1', 'Imidazoline I1', 'Imidazoline I2',
#        'Indoleamine 2,3-Dioxygenase, IDO', 'Insulin receptor',
#        'Interleukin 1-beta', 'Interleukin IL-6',
#        'Janus kinase 1 (a protein tyrosine kinase)',
#        'Janus kinase 2 (a protein tyrosine kinase)', 'KA', 'KOP', 'KOR',
#        'Kappa', 'Kappa Opiate Receptor',
#        'Kinase insert domain receptor (a type III receptor tyrosine kinase)',
#        'Kinase insert domain(KDR)', 'LIM domain kinase 1',
#        'Leukotriene 2', 'Leukotriene B4', 'Leukotriene B4 R1',
#        'Leukotriene B4 R2', 'Leukotriene Cysteinyl 1',
#        'Leukotriene Cysteinyl 2', 'Leukotriene D4', 'Leukotriene LTB4',
#        'Leukotriene b1', 'Leukotriene, Cysteinyl CysLT1',
#        'Liver X, LXR alpha', 'Liver X, LXR beta',
#        'Lymphocyte-specific protein tyrosine kinase',
#        'MAP Kinase P38 Beta', 'MAP Kinase P38 Delta',
#        'MAP Kinase P38 Gamma', 'MAP kinase',
#        'MAP kinase interacting serine/threonine kinase 2',
#        'MAP/microtubule affinity-regulating kinase 2', 'MDR1', 'MOP',
#        'MOR', 'MT1', 'MT1R', 'MT2', 'MT2R', 'Map Kinase P38 Alpha',
#        'Matrix Metalloproteinase, MMP-1',
#        'Matrix Metalloproteinase, MMP-13',
#        'Matrix Metalloproteinase, MMP-2',
#        'Matrix Metalloproteinase, MMP-3',
#        'Matrix Metalloproteinase, MMP-8',
#        'Matrix Metalloproteinase, MMP-9',
#        'Matrix Metalloproteinase, MPP-2',
#        'Matrix Metalloproteinase, MPP-9',
#        'Melanin Concentrating Hormone 1',
#        'Melanin Concentrating Hormone 2', 'Melanocortin MC1',
#        'Melanocortin MC3', 'Melanocortin MC4', 'Melanocortin MC5',
#        'Melatonin', 'Melatonin 1A', 'Melatonin 1B',
#        'Met proto-oncogene (hepatocyte growth factor receptor)',
#        'Metabotropic Glutamate 1a', 'Mineralocorticoid receptor',
#        'Mitogen-activated protein kinase 10',
#        'Mitogen-activated protein kinase 8',
#        'Mitogen-activated protein kinase 9',
#        'Mitogen-activated protein kinase kinase kinase 4',
#        'Mitogen-activated protein kinase kinase kinase 5',
#        'Mitogen-activated protein kinase kinase kinase kinase 5',
#        'Motilin', 'Mu', 'Mu Opiate Receptor',
#        'Multidrug Resistance Transporter MDR 1', 'Muscarinic',
#        'Muscarinic 1', 'Muscarinic 2', 'Muscarinic 3', 'Muscarinic 4',
#        'Muscarinic 5', 'Muscarinic Acetylcholine Receptor',
#        'Muscarinic M1', 'Muscarinic M2', 'Muscarinic M3', 'Muscarinic M4',
#        'Muscarinic M5', 'Myosin light chain kinase 2, skeletal muscle',
#        'N-Formyl Peptide Receptor FPR1',
#        'N-Formyl Peptide Receptor-Like FPRL1',
#        'NIMA (never in mitosis gene a)- related kinase 9',
#        'NIMA (never in mitosis gene a)-related kinase 2',
#        'NIMA (never in mitosis gene a)-related kinase 6', 'NK', 'NMDA',
#        'NOP', 'NPFF2', 'NPY-Y1', 'NPY-Y2', 'NPY-Y4', 'NPY-Y5', 'NRI',
#        'NT', 'Neurokinin NK1', 'Neurokinin NK2', 'Neurokinin NK3',
#        'Neuromedin B', 'Neuromedin U NMU1', 'Neuromedin U NMU2',
#        'Neuronal acetylcholine receptor protein alpha-4 subunit',
#        'Neuronal acetylcholine receptor protein alpha-7 subunit',
#        'Neuropeptide Y', 'Neuropeptide Y5 long', 'Neuropeptide Y5 short',
#        'Neurotensin 1', 'Neurotensin receptor subtype 1',
#        'Neurotrophic tyrosine kinase, receptor, type 1',
#        'Neurotrophic tyrosine kinase, receptor, type 2',
#        'Nicotinic Acetlycholine', 'Nicotinic Acetylcholine alpha1',
#        'Nicotinic Alpha2Beta2', 'Nicotinic Alpha2Beta4',
#        'Nicotinic Alpha3Beta2', 'Nicotinic Alpha3Beta4',
#        'Nicotinic Alpha4Beta2', 'Nicotinic Alpha4Beta4',
#        'Nicotinic Alpha7', 'Nicotinic neuronal, alpha-BGTX-insensitive',
#        'Nischarin', 'Nitric-oxide synthase, NOS (constitutive ) ',
#        'Nociceptin receptor', 'Nociceptin/Orphanin FQ, NOP receptor',
#        'Non-receptor tyrosine kinase Tyk2', 'Norepinephrine transporter',
#        'OPIATE Delta', 'OPIATE Kappa', 'OPIATE Kappa 3', 'OPIATE Mu',
#        'OPIATE ORL-1', 'OX1R', 'OX2R', 'Opiate non-selective',
#        'Organic Anion Transporter OATP1B3', 'Orphanin ORL1', 'Oxytocin',
#        'P21 (CDKN1A)-activated kinase 3',
#        'P21 (CDKN1A)-activated kinase 6',
#        'P21(CDKN1A)-activated kinase 4', 'P21(CDKN1A)-activated kinase 7',
#        'P21/Cdc42/Rac1-activated kinase 1 (STE20 homolog, yeast)',
#        'PACAP', 'PAF Platelet activating factor', 'PAR2',
#        'PARATHYROID HT1', 'PARATHYROID HT2', 'PCTAIRE protein kinase 1',
#        'PDGF', 'PDGF-Rbeta', 'PGD2', 'PKA', 'PKC alpha', 'PKC beta',
#        'PKC gamma', 'PKC-alpha', 'PKC-beta2',
#        'PTK2 protein tyrosine kinase 2', 'PTK6 protein tyrosine kinase 6',
#        'Phenylethanolamine-N-methyl transferase, PNMT',
#        'Phenylethanolamine-N-methyl transferase, PNMT-3',
#        'Phosphodiesterase 1', 'Phosphodiesterase 3A',
#        'Phosphodiesterase 3B', 'Phosphodiesterase 4',
#        'Phosphodiesterase 4A', 'Phosphodiesterase 4B',
#        'Phosphodiesterase 4C', 'Phosphodiesterase 4D',
#        'Phosphodiesterase 5', 'Phosphodiesterase 7A',
#        'Phosphodiesterase 8B', 'Phosphorylase kinase, gamma 1 (muscle)',
#        'Phosphorylase kinase, gamma 2 (testis)', 'Pim-1 oncogene',
#        'Pim-2 oncogene', 'Plasmepsin I', 'Plasmepsin II',
#        'Platelet-derived growth factor receptor, alpha polypeptid',
#        'Platelet-derived growth factor receptor, beta polypeptide',
#        'Potassium (voltage dependent)',
#        'Potassium Channel (Ca2+ dependent)', 'Potassium Channel HERG',
#        'Potassium channel (ATP modulatory)', 'Pregnane X receptor',
#        'Progesterone PR-B', 'Progesterone receptor',
#        'Prolactin Releasing Peptide Receptor', 'Prostaglandin D',
#        'Prostaglandin D2', 'Prostaglandin E1', 'Prostaglandin E2',
#        'Prostaglandin E3', 'Prostaglandin E4', 'Prostaglandin F',
#        'Prostaglandin I', 'Prostaglandin I2', 'Prostaglandin Transporter',
#        'Prostanid EP4', 'Prostanoid CRTH2', 'Prostanoid DP',
#        'Prostanoid EP2', 'Prostanoid, Thromboxane A2', 'Proteasome',
#        'Protein Kinase C- alpha', 'Protein Kinase C- delta',
#        'Protein Kinase D-GST',
#        'Protein kinase, AMP-activated, alpha 1 catalytic subunit',
#        'Protein kinase, cAMP-dependent, catalytic, alpha',
#        'Protein kinase, membrane associated tyrosine/threonine 1',
#        'Protein-tyrosine kinase Tie2', 'Purinergic, P2X',
#        'Purinergic, P2X1', 'Purinergic, P2X3', 'Purinergic, P2X4',
#        'Purinergic, P2X7', 'Purinergic, P2Y', 'PurinergicP2X2/3',
#        'Receptor-interacting serine-threonine kinase 2',
#        'Ret proto-oncogene', 'Retinoid X Receptor RXRalpha',
#        'Ribosomal protein S6 kinase, 90kDa, polypeptide 2',
#        'Ribosomal protein S6 kinase, 90kDa, polypeptide 3',
#        'Ribosomal protein S6 kinase, 90kDa, polypeptide 5', 'SERT',
#        'SOMATOSTATIN', 'SOMATOSTATIN SST1', 'SOMATOSTATIN SST2',
#        'SOMATOSTATIN SST3', 'SOMATOSTATIN SST4', 'SOMATOSTATIN SST5',
#        'STE20-like kinase (yeast)', 'Serine/threonine kinase 10',
#        'Serine/threonine kinase 16',
#        'Serine/threonine kinase 17a (apoptosis-inducing)',
#        'Serine/threonine kinase 17b (apoptosis-inducing)',
#        'Serine/threonine kinase 18', 'Serine/threonine kinase 3 mouse',
#        'Serine/threonine kinase 36 (fused homolog, Drosophila)',
#        'Serine/threonine kinase 38 like', 'Serine/threonine kinase 4',
#        'Serine/threonine kinase 6', 'Serotonin', 'Serotonin 5-HT1A',
#        'Serotonin 5-HT2A', 'Serotonin 5-HT2B', 'Serotonin 5-HT2C',
#        'Serotonin 5-HT7', 'Serotonin Transporter',
#        'Serotonin Transporter (SERT)',
#        'Serum/glucocorticoid regulated kinase', 'Sigma', 'Sigma 1',
#        'Sigma 2', 'Sigma 2 PC12', 'Sigma-1', 'Sigma-2',
#        'Signal transducer and activator of transcription 3,Stat3',
#        'Smoothened', 'Sodium (Site 1)', 'Sodium (Site 2)',
#        'Sodium Channel', 'Sodium Channel, Site 2',
#        'Spleen tyrosine kinase', 'Substance P', 'TA1', 'TAAR1',
#        'TEK tyrosine kinase, endothelial (venous malformations, multiple cutaneous and mucosal)',
#        'TG 1019', 'TNF-alpha', 'TP', 'TRAF2 and NCK interacting kinase',
#        'TRH', 'TTK protein kinase', 'Tachykinin NK1', 'Tachykinin NK2',
#        'Tachykinin NK3', 'Thrombin', 'Thrombin FIIa', 'Thrombin FXa',
#        'Thrombin trypsin', 'Thromboxane', 'Thromboxane A2',
#        'Thromboxane Alpha', 'Thromboxane B2', 'Thromboxane Beta',
#        'Thromboxane prostanoid', 'Thymidylate Synthase',
#        'Topoisomerase I', 'Tumor Necrosis Factor, Non-selective',
#        'Tyrosine kinase receptor ron', 'Urotensin II', 'Urotensin-II',
#        'V-abl Abelson murine leukemia viral oncogene homolog',
#        'V-abl Abelson murine leukemia viral oncogene homolog 1',
#        'V-abl Abelson murine leukemia viral oncogene homolog 1 (E255K)',
#        'V-abl Abelson murine leukemia viral oncogene homolog 1 (H396P)',
#        'V-abl Abelson murine leukemia viral oncogene homolog 1 (M351T)',
#        'V-abl Abelson murine leukemia viral oncogene homolog 1 (Q252H)',
#        'V-abl Abelson murine leukemia viral oncogene homolog 1 (T3151)',
#        'V-abl Abelson murine leukemia viral oncogene homolog 1 (Y253F)',
#        'V-abl Abelson murine leukemia viral oncogene homolog 2',
#        'V-erb-b2 erythroblastic leukemia viral oncogene homolog 2',
#        'V-kit Hardy-Zuckerman 4 feline sarcoma viral oncogene homolog (avian)',
#        'V-src sarcoma (Schmidt-Ruppin A-2) viral oncogene homolog (avian)',
#        'V-yes-1 Yamaguchi sarcoma viral oncogene homolog 1',
#        'V-yes-1 Yamaguchi sarcoma viral related oncogene homolog', 'V1',
#        'V2', 'VASOPRESSIN V1', 'VASOPRESSIN V1A', 'VASOPRESSIN V1B',
#        'VASOPRESSIN V2', 'VEGF-R2', 'VIP', 'VIP 1', 'VIP 2', 'VMAT1',
#        'VMAT2', 'Vanilloid VR1', 'Vascular Endothelial Growth Factor',
#        'Vasoactive Intestinal Peptide 1', 'Vasopressin V3',
#        'Vitamin D, VDR', 'Vitamin D3',
#        'Zeta-chain (TCR) associated protein kinase 70kDa',
#        'adrenergic Alpha1', 'adrenergic Alpha1A', 'adrenergic Alpha1B',
#        'adrenergic Alpha1C', 'adrenergic Alpha1D', 'adrenergic Alpha2',
#        'adrenergic Alpha2A', 'adrenergic Alpha2B', 'adrenergic Alpha2C',
#        'adrenergic Beta', 'adrenergic Beta1', 'adrenergic Beta2',
#        'adrenergic Beta3', 'aldose reductase', 'alpha-2C', 'alpha1',
#        'alpha1-Adrenocepter', 'alpha1-GABA-A', 'alpha1A', 'alpha1B',
#        'alpha1beta3gamma2', 'alpha2', 'alpha2-Adrenocepter',
#        'alpha2-GABA-A', 'alpha2beta2', 'alpha2beta3gamma2', 'alpha2beta4',
#        'alpha3-GABA-A', 'alpha3beta2', 'alpha3beta3gamma2', 'alpha3beta4',
#        'alpha4beta2', 'alpha4beta3gamma2', 'alpha4beta4', 'alpha5-GABA-A',
#        'alpha5beta3gamma2', 'alpha6-GABA-A', 'alpha6beta3gamma2',
#        'alpha7', 'alphabeta3gamma2', 'androgen', 'beta-amyloid', 'beta1',
#        'beta2', 'beta3', 'calcineurin', 'calmodulin kinase', 'calpain',
#        'calpain-1', 'casein kinase-1', 'casein kinase-2', 'caspase-2',
#        'caspase-3', 'caspase-6', 'caspase-7', 'caspase-8', 'dUTPase',
#        'estrogen alpha', 'estrogen beta', 'estrogen, ER alpha',
#        'estrogen, ER beta', 'glucagon', 'h5-HT1A', 'h5-HT2A', 'h5-HT2B',
#        'hD2L', 'hD3', 'hH1', 'hM1', 'hY1', 'hY2', 'hY5',
#        'halpha1B-adrenergic', 'halpha2C-adrenergic',
#        'insulin kinase-beta', 'mGluR5', 'malonyl-CoA decarboxylase, MCD',
#        'metabotropic glutamate 1', 'metabotropic glutamate 1b',
#        'metabotropic glutamate 1c', 'metabotropic glutamate 2',
#        'metabotropic glutamate 3', 'metabotropic glutamate 3/1a',
#        'metabotropic glutamate 3/1c', 'metabotropic glutamate 4',
#        'metabotropic glutamate 4a', 'metabotropic glutamate 5',
#        'metabotropic glutamate 5a', 'metabotropic glutamate 6',
#        'metabotropic glutamate 7', 'metabotropic glutamate 8',
#        'mineralocorticoid', 'nicotinic central', 'noradrenaline-alpha1',
#        'noradrenaline-alpha2A', 'noradrenaline-alpha2C', 'ouabain',
#        'papain', 'phencyclidine', 'progesterone',
#        'sphingosine-1-phosphate 1 S1P1', 'sphingosine-1-phosphate 3 S1P3',
#        'sphingosine-1-phosphate 4 S1P4', 'sphingosine-1-phosphate 5 S1P5',
#        'tachykinin'], dtype=object)

# %%
substance_name = "lsd"
substance_filter = ki_db_human[" Ligand Name"].str.lower() == (substance_name)
substance_df = ki_db_human[substance_filter][["Name"," Ligand Name", "ki Val"]]
substance_df = substance_df[substance_df["ki Val"] < 10000]
substance_df
# Out:
#                              Name  Ligand Name       ki Val
# 284                        5-HT1A          LSD     0.640000
# 290                        5-HT1A          LSD     4.920000
# 1106                       5-HT1D          LSD    14.000000
# 2351                       5-HT2A          LSD     0.950000
# 2356                       5-HT2A          LSD     2.560000
# 13956                      5-HT1A          LSD     1.090000
# 19838                      5-HT1A          LSD     1.100000
# 24627                       5-HT6          LSD     2.290868
# 25593                      5-HT2A          LSD     5.200000
# 25594                      5-HT2A          LSD     2.700000
# 37101                      5-HT2A          LSD    21.379621
# 37123                      5-HT2B          LSD     8.912509
# 37143                      5-HT2C          LSD    45.708819
# 37166                      5-HT2A          LSD     0.758578
# 37190                      5-HT2B          LSD     0.977237
# 37214                      5-HT2C          LSD     1.096478
# 55407                      5-HT2B          LSD     3.715352
# 76133                      5-HT1A          LSD     7.300000
# 80444                      5-HT1A          LSD     2.780000
# 80445                      5-HT2A          LSD     0.710000
# 80446                      5-HT2C          LSD     2.910000
# 80469                      5-HT2A          LSD     0.720000
# 80478                      5-HT2A          LSD     0.475000
# 80496  Norepinephrine transporter          LSD  5600.000000
# 80504                          D1          LSD   273.000000
# 80525                          D4          LSD   330.000000
# 80526                          D3          LSD    27.100000
# 80527                          D2          LSD    38.800000
# 87243                      5-HT1A          LSD     3.000000
# 87268                      5-HT2A          LSD     4.200000
# 87293                      5-HT2C          LSD    15.000000
# 87318                     alpha1A          LSD   670.000000
# 87342                     Alpha2A          LSD    12.000000
# 87367                          D1          LSD   310.000000
# 87392                          D2          LSD    25.000000
# 87417                          D3          LSD    96.000000
# 87567                          H1          LSD  1100.000000
# 91302                      5-HT1A          LSD     1.500000
# 91318                      5-HT2A          LSD     5.300000
# 91334                      5-HT2C          LSD    14.000000

# %%
substance_name = "DMT,5-MeO".lower()
substance_filter = ki_db_human[" Ligand Name"].str.contains(substance_name, case=False)
substance_df = ki_db_human[substance_filter][["Name", "ki Val"]]
substance_df = substance_df[substance_df["ki Val"] < 10000]
substance_df.groupby("Name").mean()
# Out:
#                             ki Val
# Name
# 5-HT1A                         1.9
# 5-HT1B                        74.0
# 5-HT1D                         6.3
# 5-HT1E                       360.2
# 5-HT2A                      1109.0
# 5-HT2B                      3884.0
# 5-HT2C                       538.0
# 5-HT5a                       276.6
# 5-HT6                         35.5
# 5-HT7                          3.9
# Alpha2A                     1890.0
# Alpha2B                     2640.0
# Alpha2C                      508.1
# D1                            79.5
# D2                          3562.0
# D3                           497.6
# D4                          3120.0
# Imidazoline 1               2498.0
# MT1R                         210.0
# MT2R                          16.0
# Norepinephrine transporter  2859.0
# SERT                        2032.0

# %%
receptor_name = "cannabi"
receptor_filter = ki_db_human["Name"].str.contains(receptor_name, case=False)
receptor_df = ki_db_human[receptor_filter][["Name"," Ligand Name", "ki Val"]]
receptor_df["Name"].unique()
# Out:
# array(['CANNABINOID CB2', 'CANNABINOID CB1'], dtype=object)
